-- %%
%sql
CREATE TABLE employess
(id INT, name STRING, salary DOUBLE)

-- %%
%sql
Select * from employess

-- %%
%sql
Insert into employess values 
(1, 'John', 100000),
(2, 'Mike', 20000),
(3, 'Sara', 300000),
(4, 'Tom', 40000)

-- %%
%sql
UPDATE EMPLOYESS SET salary =600000 WHERE SALARY < 50000

-- %%
%sql DESCRIBE detail employess
-- Out:
-- Databricks data profile. Run in Databricks to view.

-- %%
%sql
DESCRIBE HISTORY employess

-- %%
SElect * from employess@v2

-- %%
DELETE FROM employess

-- %%
restore table employess to version AS of 3

-- %%
optimize employess zorder by id

-- %%
vacuum employess retain 0 hours

-- %%
describe extended employess

-- %%
create table external_default (width int, length int, height int) location '/mnt/data/external_default';

-- %%
%fs ls 'dbfs:/databricks-datasets/'

-- %%
create database managed_demo;
